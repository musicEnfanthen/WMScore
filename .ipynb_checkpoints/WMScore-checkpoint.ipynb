# %%
################
# IMPORTS

import requests
from music21 import *

# %%
################
# ENVIRONMENT

#
# settings for correct environment paths to MuseScore & Lilypond
# 
# (comment out the parts not needed)
#

env = environment.Environment()
# env['musicxmlPath'] = 'path/to/your/musicXmlApplication'
# env['musescoreDirectPNGPath'] = 'path/to/your/museScore'
# env['lilypondPath'] = path/to/your/lilypond'

# on WIN:
#env['musicxmlPath'] = 'C:/Program Files (x86)/MuseScore 2/bin/MuseScore.exe'
#env['musescoreDirectPNGPath'] = 'C:/Program Files (x86)/MuseScore 2/bin/MuseScore.exe'
#env['lilypondPath'] = 'C:/Program Files (x86)/LilyPond/usr/bin/lilypond.exe'

# on Mac:
env['musicxmlPath'] = '/Applications/MuseScore 2.app/Contents/MacOS/mscore'
env['musescoreDirectPNGPath'] = '/Applications/MuseScore 2.app/Contents/MacOS/mscore'
env['lilypondPath'] = '/Applications/Lilypond.app'

# on Linux:
# env['musicxmlPath'] = '/usr/bin/musescore'
# env['musescoreDirectPNGPath'] = '/usr/bin/musescore'
# env['lilypondPath'] = '/usr/bin/lilypond'


print('Environment settings:')
print('musicXML:  ', env['musicxmlPath'])
print('musescore: ', env['musescoreDirectPNGPath'])
print('lilypond:  ', env['lilypondPath'])
# Out:
# Environment settings:
# musicXML:   /Applications/MuseScore 2.app/Contents/MacOS/mscore
# musescore:  /Applications/MuseScore 2.app/Contents/MacOS/mscore
# lilypond:   /Applications/Lilypond.app

# %%
################
# INIT

# routes to football-data api
apiRoot = 'http://api.football-data.org/v1'
apiWM2018Route = '/competitions/467'
apiFixtures = '/fixtures'
apiTeams = '/teams'

apiUrl_fixtures = apiRoot + apiWM2018Route + apiFixtures
apiUrl_teams = apiRoot + apiWM2018Route + apiTeams

print(apiUrl_fixtures)
print(apiUrl_teams)
# Out:
# http://api.football-data.org/v1/competitions/467/fixtures
# http://api.football-data.org/v1/competitions/467/teams

# %%
################
# FUNCTIONS


# FUNCTION to check the status of an http request
def checkRequestStatus(request):
    "This function checks the status of an http request and prints further information for failing requests"
    if not request.status_code == 200:
        print(request)
        print(request.status_code)
        print(request.headers)
    return


# FUNCTION to create note object dictionaries per team
def createNoteObjectsPerTeam(teamNoteObject):
    "This function returns a dictionary of 3 music21 note objects"
    teamNoteObject =  {1: note.Note(), 2: note.Note(), 3: note.Note()}
    return teamNoteObject


# FUNCTION to get the shortcode of a team
# teamHref: 'http://api.football-data.org/v1/teams/XXX' with XXX: 3-digit team id
def getTeamCodeFromApi(teamHref):
    "This function returns the shortcode of a team"
    for team in teams:
        if (teamHref == team['_links']['self']['href']):
            return team['code']

        
# FUNCTION go get data about a single match
def getMatchShortData(fixture):
    "This function returns a dictionary with compacted data about a single match, including homeTeamCode, homeResult, awayTeamCode, awayResult, status & matchDay"
    match = {}
    homeTeamHref = fixture['_links']['homeTeam']['href']
    match['homeTeamCode'] = getTeamCodeFromApi(homeTeamHref)
    match['homeResult'] = fixture['result']['goalsHomeTeam']
    awayTeamHref = fixture['_links']['awayTeam']['href']
    match['awayTeamCode'] = getTeamCodeFromApi(awayTeamHref)
    match['awayResult'] = fixture['result']['goalsAwayTeam']
    match['matchDay'] = fixture['matchday']
    match['status'] = fixture['status']
    return match


# FUNCTION to append list items to a stream
def appendListItemToStream(listItem, s):
    "This function iterates over a list and appends the single items to a stream s"
    for item in listItem:
        s.append(item)
    return

# %%
################
# HTTP REQUESTS

# HTTP request 1: get teams from football-data api
r1 = requests.get(apiUrl_teams)
checkRequestStatus(r1)

#store results from request
teamsCount = r1.json()['count']
teams = r1.json()['teams']

print('number of teams: ', teamsCount)
print(teams)
# Out:
# number of teams:  32
# [{'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/808'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/808/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/808/players'}}, 'name': 'Russia', 'code': 'RUS', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Russia.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/801'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/801/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/801/players'}}, 'name': 'Saudi Arabia', 'code': 'KSA', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/0/0d/Flag_of_Saudi_Arabia.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/825'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/825/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/825/players'}}, 'name': 'Egypt', 'code': 'EGY', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/f/fe/Flag_of_Egypt.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/758'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/758/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/758/players'}}, 'name': 'Uruguay', 'code': 'URU', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/f/fe/Flag_of_Uruguay.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/815'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/815/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/815/players'}}, 'name': 'Morocco', 'code': 'MAR', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/2/2c/Flag_of_Morocco.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/840'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/840/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/840/players'}}, 'name': 'Iran', 'code': 'IRN', 'shortName': 'Iran', 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/c/ca/Flag_of_Iran.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/765'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/765/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/765/players'}}, 'name': 'Portugal', 'code': 'POR', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/5/5c/Flag_of_Portugal.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/760'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/760/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/760/players'}}, 'name': 'Spain', 'code': 'ESP', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/9/9a/Flag_of_Spain.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/773'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/773/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/773/players'}}, 'name': 'France', 'code': 'FRA', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/c/c3/Flag_of_France.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/779'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/779/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/779/players'}}, 'name': 'Australia', 'code': 'AUS', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/b/b9/Flag_of_Australia.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/7 ...

# %%
# # HTTP request 2: get fixtures from football-data api
r2 = requests.get(apiUrl_fixtures)
checkRequestStatus(r2)

#store results from request
fixturesCount = r2.json()['count']
fixtures = r2.json()['fixtures']

print('number of fixtures: ', fixturesCount)
print(fixtures)
# Out:
# number of fixtures:  64
# [{'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165069'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/808'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/801'}}, 'date': '2018-06-14T15:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Russia', 'awayTeamName': 'Saudi Arabia', 'result': {'goalsHomeTeam': 5, 'goalsAwayTeam': 0, 'halfTime': {'goalsHomeTeam': 2, 'goalsAwayTeam': 0}}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165084'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/825'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/758'}}, 'date': '2018-06-15T12:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Egypt', 'awayTeamName': 'Uruguay', 'result': {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165083'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/815'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/840'}}, 'date': '2018-06-15T15:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Morocco', 'awayTeamName': 'Iran', 'result': {'goalsHomeTeam': 0, 'goalsAwayTeam': 1, 'halfTime': {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165076'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/765'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/760'}}, 'date': '2018-06-15T18:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Portugal', 'awayTeamName': 'Spain', 'result': {'goalsHomeTeam': 3, 'goalsAwayTeam': 3}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165072'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/773'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/779'}}, 'date': '2018-06-16T10:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'France', 'awayTeamName': 'Australia', 'result': {'goalsHomeTeam': 2, 'goalsAwayTeam': 1, 'halfTime': {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165073'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/762'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1066'}}, 'date': '2018-06-16T13:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Argentina', 'awayTeamName': 'Iceland', 'result': {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165071'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/832'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/782'}}, 'date': '2018-06-16T16:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Peru', 'awayTeamName': 'Denmark', 'result': {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165074'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/799'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/776'}}, 'date': '2018-06-16T19:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Croatia', 'awayTeamName': 'Nigeria', 'result': {'goalsHomeTeam': 2, 'goalsAway ...

# %%
# create dictionary of groups and their resp. teams
  
# init variables
groupsWithTeamsDict = {}                                        # empty dictionary to populate with groups and their teams 
groupLabel = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']           # array of group labels (strings)
groupsDict = [                                                  # API returns no group infos, so it has to be added manually   
    {'RUS': {}, 'KSA': {}, 'EGY': {}, 'URU': {}},
    {'MAR': {}, 'IRN': {}, 'ESP': {}, 'POR': {}},
    {'FRA': {}, 'DEN': {}, 'AUS': {}, 'PER': {}},
    {'CRO': {}, 'NGA': {}, 'ISL': {}, 'ARG': {}},
    {'BRA': {}, 'SUI': {}, 'CRC': {}, 'SRB': {}},
    {'GER': {}, 'MEX': {}, 'SWE': {}, 'KOR': {}},
    {'BEL': {}, 'PAN': {}, 'TUN': {}, 'ENG': {}},
    {'COL': {}, 'JPN': {}, 'POL': {}, 'SEN': {}}
]                      


# create dictionary
if (len(groupLabel) == len(groupsDict)):
    for i in range(len(groupLabel)):
        # iterate over teams per group
        for teamCode, teamNoteObject in groupsDict[i].items():
            # create note object for every single team
            groupsDict[i][teamCode] = createNoteObjectsPerTeam(teamNoteObject)  
        # populate groupsWithTeamsDict with groupLabel and the 4 teams for each group
        groupsWithTeamsDict[groupLabel[i]] = groupsDict[i]
        

print(groupsWithTeamsDict)
# Out:
# {'A': {'RUS': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KSA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'EGY': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'URU': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'B': {'MAR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'IRN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ESP': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'C': {'FRA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'DEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'AUS': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'D': {'CRO': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'NGA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ISL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ARG': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'E': {'BRA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SUI': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'CRC': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SRB': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'F': {'GER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'MEX': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SWE': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KOR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'G': {'BEL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PAN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'TUN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ENG': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'H': {'COL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'JPN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}}

# %%
# create list of matches and their resp. data

# init
matches = []

# get matchdata for finished matches
for fixture in fixtures:
    # consider only finished matches
    if fixture['status'] == 'FINISHED': 
        # get compact data about match 
        matches.append(getMatchShortData(fixture))

print(matches)
# Out:
# [{'homeTeamCode': 'RUS', 'homeResult': 5, 'awayTeamCode': 'KSA', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'EGY', 'homeResult': 0, 'awayTeamCode': 'URU', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'MAR', 'homeResult': 0, 'awayTeamCode': 'IRN', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'POR', 'homeResult': 3, 'awayTeamCode': 'ESP', 'awayResult': 3, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'FRA', 'homeResult': 2, 'awayTeamCode': 'AUS', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'ARG', 'homeResult': 1, 'awayTeamCode': 'ISL', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'PER', 'homeResult': 0, 'awayTeamCode': 'DEN', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'CRO', 'homeResult': 2, 'awayTeamCode': 'NGA', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'CRC', 'homeResult': 0, 'awayTeamCode': 'SRB', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'GER', 'homeResult': 0, 'awayTeamCode': 'MEX', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'BRA', 'homeResult': 1, 'awayTeamCode': 'SUI', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'SWE', 'homeResult': 1, 'awayTeamCode': 'KOR', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'BEL', 'homeResult': 3, 'awayTeamCode': 'PAN', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'TUN', 'homeResult': 1, 'awayTeamCode': 'ENG', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'COL', 'homeResult': 1, 'awayTeamCode': 'JPN', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'POL', 'homeResult': 1, 'awayTeamCode': 'SEN', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'RUS', 'homeResult': 3, 'awayTeamCode': 'EGY', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'POR', 'homeResult': 1, 'awayTeamCode': 'MAR', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'URU', 'homeResult': 1, 'awayTeamCode': 'KSA', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'IRN', 'homeResult': 0, 'awayTeamCode': 'ESP', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'DEN', 'homeResult': 1, 'awayTeamCode': 'AUS', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'FRA', 'homeResult': 1, 'awayTeamCode': 'PER', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'ARG', 'homeResult': 0, 'awayTeamCode': 'CRO', 'awayResult': 3, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'BRA', 'homeResult': 2, 'awayTeamCode': 'CRC', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'NGA', 'homeResult': 2, 'awayTeamCode': 'ISL', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'SRB', 'homeResult': 1, 'awayTeamCode': 'SUI', 'awayResult': 2, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'BEL', 'homeResult': 5, 'awayTeamCode': 'TUN', 'awayResult': 2, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'KOR', 'homeResult': 1, 'awayTeamCode': 'MEX', 'awayResult': 2, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'GER', 'homeResult': 2, 'awayTeamCode': 'SWE', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'ENG', 'homeResult': 6, 'awayTeamCode': 'PAN', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'JPN', 'homeResult': 2, 'awayTeamCode': 'SEN', 'awayResult': 2, 'matchDay': 2, 'status': 'FINISHED'}, {'homeTeamCode': 'POL', 'homeResult': 0, 'awayTeamCode': 'COL', 'awayResult': 3, 'matchDay': 2, 'status': 'FINISHED'}]

# %%
# populate groupsWithTeamsDict with match results

# iterate over matches
for match in matches:
    print('match: ', match)
    # iterate over groups
    for groupKey, groupValue in groupsWithTeamsDict.items():
        # init shortcuts
        homeCode = match['homeTeamCode']
        awayCode = match['awayTeamCode']
        matchDay = match['matchDay']
        homeResult = match['homeResult']
        awayResult = match['awayResult']
        
        # find teamcodes in groups 
        if homeCode and awayCode in groupValue:
            
            print('groupValue: ', groupValue)
            
            # add match results as pitchClasses to music21 note objects in groups dictionary
            homeNote = groupValue[homeCode][matchDay]
            awayNote = groupValue[awayCode][matchDay]
            homeNote.pitch.pitchClass = homeResult
            awayNote.pitch.pitchClass = awayResult
            
            # add group label to match dictionary
            match['group'] = groupKey
            
            # transform match results to chord objects with result strings as lyrics and add them all to match dictionary
            separator = ': '            
            match['gameChord'] = chord.Chord([homeNote, awayNote])
            match['gameChord'].addLyric(homeCode + separator + str(homeResult))
            match['gameChord'].addLyric(awayCode + separator + str(awayResult))
            # print(match)
# Out:
# match:  {'homeTeamCode': 'RUS', 'homeResult': 5, 'awayTeamCode': 'KSA', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'RUS': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KSA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'EGY': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'URU': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'EGY', 'homeResult': 0, 'awayTeamCode': 'URU', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'RUS': {1: <music21.note.Note F>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KSA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'EGY': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'URU': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'MAR', 'homeResult': 0, 'awayTeamCode': 'IRN', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'MAR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'IRN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ESP': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'POR', 'homeResult': 3, 'awayTeamCode': 'ESP', 'awayResult': 3, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'MAR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'IRN': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ESP': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'FRA', 'homeResult': 2, 'awayTeamCode': 'AUS', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'FRA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'DEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'AUS': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'ARG', 'homeResult': 1, 'awayTeamCode': 'ISL', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'CRO': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'NGA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ISL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ARG': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'PER', 'homeResult': 0, 'awayTeamCode': 'DEN', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'FRA': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'DEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'AUS': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'CRO', 'homeResult': 2, 'awayTeamCode': 'NGA', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'CRO': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'NGA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ISL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ARG': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'CRC', 'homeResult': 0, 'awayTeamCode': 'SRB', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'BRA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SUI': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'CRC': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SRB': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'GER', 'homeResult': 0, 'awayTeamCode': 'MEX', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'GER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'MEX': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SWE': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KOR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'BRA', 'homeResult': 1, 'awayTeamCode': 'SUI', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'BRA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SUI': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'CRC': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SRB': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'SWE', 'homeResult': 1, 'awayTeamCode': 'KOR', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'GER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'MEX': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SWE': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KOR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'BEL', 'homeResult': 3, 'awayTeamCode': 'PAN', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'BEL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PAN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'TUN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ENG': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'TUN', 'homeResult': 1, 'awayTeamCode': 'ENG', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'BEL': {1: <music21.note.Note E->, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PAN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'TUN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ENG': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'COL', 'homeResult': 1, 'awayTeamCode': 'JPN', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'COL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'JPN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'POL', 'homeResult': 1, 'awayTeamCode': 'SEN', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED'}
# groupValue:  {'COL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'JPN': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'RUS', 'homeResult': 3, 'awayTeamCode': 'EGY', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'RUS': {1: <music21.note.Note F>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KSA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'EGY': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'URU': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'POR', 'homeResult': 1, 'awayTeamCode': 'MAR', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'MAR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'IRN': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ESP': {1: <music21.note.Note E->, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POR': {1: <music21.note.Note E->, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'URU', 'homeResult': 1, 'awayTeamCode': 'KSA', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'RUS': {1: <music21.note.Note F>, 2: <music21.note.Note E->, 3: <music21.note.Note C>}, 'KSA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'EGY': {1: <music21.note.Note C>, 2: <music21.note.Note C#>, 3: <music21.note.Note C>}, 'URU': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'IRN', 'homeResult': 0, 'awayTeamCode': 'ESP', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'MAR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'IRN': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ESP': {1: <music21.note.Note E->, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POR': {1: <music21.note.Note E->, 2: <music21.note.Note C#>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'DEN', 'homeResult': 1, 'awayTeamCode': 'AUS', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'FRA': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'DEN': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'AUS': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'FRA', 'homeResult': 1, 'awayTeamCode': 'PER', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'FRA': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'DEN': {1: <music21.note.Note C#>, 2: <music21.note.Note C#>, 3: <music21.note.Note C>}, 'AUS': {1: <music21.note.Note C#>, 2: <music21.note.Note C#>, 3: <music21.note.Note C>}, 'PER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'ARG', 'homeResult': 0, 'awayTeamCode': 'CRO', 'awayResult': 3, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'CRO': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'NGA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ISL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ARG': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'BRA', 'homeResult': 2, 'awayTeamCode': 'CRC', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'BRA': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SUI': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'CRC': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SRB': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'NGA', 'homeResult': 2, 'awayTeamCode': 'ISL', 'awayResult': 0, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'CRO': {1: <music21.note.Note D>, 2: <music21.note.Note E->, 3: <music21.note.Note C>}, 'NGA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ISL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ARG': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'SRB', 'homeResult': 1, 'awayTeamCode': 'SUI', 'awayResult': 2, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'BRA': {1: <music21.note.Note C#>, 2: <music21.note.Note D>, 3: <music21.note.Note C>}, 'SUI': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'CRC': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SRB': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'BEL', 'homeResult': 5, 'awayTeamCode': 'TUN', 'awayResult': 2, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'BEL': {1: <music21.note.Note E->, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PAN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'TUN': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ENG': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'KOR', 'homeResult': 1, 'awayTeamCode': 'MEX', 'awayResult': 2, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'GER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'MEX': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SWE': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KOR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'GER', 'homeResult': 2, 'awayTeamCode': 'SWE', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'GER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'MEX': {1: <music21.note.Note C#>, 2: <music21.note.Note D>, 3: <music21.note.Note C>}, 'SWE': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KOR': {1: <music21.note.Note C>, 2: <music21.note.Note C#>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'ENG', 'homeResult': 6, 'awayTeamCode': 'PAN', 'awayResult': 1, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'BEL': {1: <music21.note.Note E->, 2: <music21.note.Note F>, 3: <music21.note.Note C>}, 'PAN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'TUN': {1: <music21.note.Note C#>, 2: <music21.note.Note D>, 3: <music21.note.Note C>}, 'ENG': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'JPN', 'homeResult': 2, 'awayTeamCode': 'SEN', 'awayResult': 2, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'COL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'JPN': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SEN': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}
# match:  {'homeTeamCode': 'POL', 'homeResult': 0, 'awayTeamCode': 'COL', 'awayResult': 3, 'matchDay': 2, 'status': 'FINISHED'}
# groupValue:  {'COL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'JPN': {1: <music21.note.Note D>, 2: <music21.note.Note D>, 3: <music21.note.Note C>}, 'POL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SEN': {1: <music21.note.Note D>, 2: <music21.note.Note D>, 3: <music21.note.Note C>}}

# %%
# group matches as chord pairs per matchday

# init
groupChordsByMatchDay = {}

# get matchDays with group matches as chord pairs
for i in range(1, 4):
    # iterate over matchDays (1-3)
    matchDayChordPairsList = []

    for label in groupLabel:
        # iterate over group label (A-H)
        matchChordPairList = []
        for match in matches:
            # iterate over matches and check for correct matchday and group
            if match['matchDay'] == i:                       
                if label == match['group']:
                    if 'gameChord' in match:
                        # add existing chords to pair list
                        matchChordPairList.append(match['gameChord'])
        if matchChordPairList:
            # add existing pair lists to matchday
            matchDayChordPairsList.append(matchChordPairList)
    # populate dictionary with matchdays and their resp. pair lists
    groupChordsByMatchDay[i] = matchDayChordPairsList


print(groupChordsByMatchDay)
# Out:
# {1: [[<music21.chord.Chord F4 C4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord E-4 E-4>], [<music21.chord.Chord D4 C#4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C#4 C#4>, <music21.chord.Chord D4 C4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord C#4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord E-4 C4>, <music21.chord.Chord C#4 D4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord C#4 D4>]], 2: [[<music21.chord.Chord E-4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord C#4 C4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C#4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord C4 E-4>, <music21.chord.Chord D4 C4>], [<music21.chord.Chord D4 C4>, <music21.chord.Chord C#4 D4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord D4 C#4>], [<music21.chord.Chord F4 D4>, <music21.chord.Chord F#4 C#4>], [<music21.chord.Chord D4 D4>, <music21.chord.Chord C4 E-4>]], 3: []}

# %%
# create final WMScore stream

# init
groupStreamParts = []     # empty list as container for groups as music21 stream.Part objects


# init empty parts (stream.Part) for every group
for i in range(len(groupLabel)):
    groupString = 'Group ' + groupLabel[i]
    groupStreamParts.append(stream.Part(id=groupString))
    groupStreamParts[i].partName = groupString    
    

# populate groupStreamParts with groupChords
# iterate over matchdays
for matchDay, groupChordPairs in groupChordsByMatchDay.items():
    
    # iterate over groupChordPairs of a matchday
    for i in range(len(groupChordPairs)):
        
        # create music21 measure object with matchday as number
        matchDayMeasure = stream.Measure(number=matchDay)
        
        # iterate over every chord of a chordPair and append it to matchday measure
        for k in range(len(groupChordPairs[i])):
            matchDayMeasure.append(groupChordPairs[i][k])
        
        # check for match of i with length of part list
        if i >= len(groupStreamParts):            
            break
        # append matchday measure to resp. part stream
        groupStreamParts[i].append(matchDayMeasure)        

            
# create final WMScore stream object (stream.Stream)
WMScore = stream.Stream(id='WMScore')

# append all groups (stream.Parts) to final WMScore (stream.Stream)
appendListItemToStream(groupStreamParts, WMScore)

WMScore.show('text')
# Out:
# {0.0} <music21.stream.Part Group A>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord F4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord E-4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
# {4.0} <music21.stream.Part Group B>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord E-4 E-4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
# {8.0} <music21.stream.Part Group C>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
# {12.0} <music21.stream.Part Group D>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C4 E-4>
#         {1.0} <music21.chord.Chord D4 C4>
# {16.0} <music21.stream.Part Group E>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
# {20.0} <music21.stream.Part Group F>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord D4 C#4>
# {24.0} <music21.stream.Part Group G>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord E-4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord F4 D4>
#         {1.0} <music21.chord.Chord F#4 C#4>
# {28.0} <music21.stream.Part Group H>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 D4>
#         {1.0} <music21.chord.Chord C4 E-4>

# %%
################
# METADATA

WMScore.insert(0.0, metadata.Metadata())
WMScore.metadata.title = '#WMScore 2018'
WMScore.metadata.composer = 'transcoded by @musicenfanthen'
WMScore.metadata.date = metadata.DateBetween(['2018/06/14','2018/06/25'])


################
# TEMPO

# add tempo at first measure: quarter = 90 (minutes per game) 
firstMeasure = groupStreamParts[0].measure(1)                         
firstMeasure.insert(0.0, tempo.MetronomeMark(number=90))


WMScore.show('text')
# Out:
# {0.0} <music21.metadata.Metadata object at 0x106eb7080>
# {0.0} <music21.stream.Part Group A>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.tempo.MetronomeMark maestoso Quarter=90>
#         {0.0} <music21.chord.Chord F4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord E-4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
# {4.0} <music21.stream.Part Group B>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord E-4 E-4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
# {8.0} <music21.stream.Part Group C>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
# {12.0} <music21.stream.Part Group D>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C4 E-4>
#         {1.0} <music21.chord.Chord D4 C4>
# {16.0} <music21.stream.Part Group E>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
# {20.0} <music21.stream.Part Group F>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord D4 C#4>
# {24.0} <music21.stream.Part Group G>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord E-4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord F4 D4>
#         {1.0} <music21.chord.Chord F#4 C#4>
# {28.0} <music21.stream.Part Group H>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 D4>
#         {1.0} <music21.chord.Chord C4 E-4>

# %%
WMScore.show()
