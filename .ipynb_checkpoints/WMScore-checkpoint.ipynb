# %%
import requests
from music21 import *

# %%
env = environment.Environment()
# env['musicxmlPath'] = 'path/to/your/musicXmlApplication'
# env['musescoreDirectPNGPath'] = 'path/to/your/museScore'
# env['lilypondPath'] = path/to/your/lilypond'

# on WIN:
env['musicxmlPath'] = 'C:/Program Files (x86)/MuseScore 2/bin/MuseScore.exe'
env['musescoreDirectPNGPath'] = 'C:/Program Files (x86)/MuseScore 2/bin/MuseScore.exe'
env['lilypondPath'] = 'C:/Program Files (x86)/LilyPond/usr/bin/lilypond.exe'

# on Mac
#env['musicxmlPath'] = '/Applications/MuseScore 2.app/Contents/MacOS/mscore'
#env['musescoreDirectPNGPath'] = '/Applications/MuseScore 2.app/Contents/MacOS/mscore'
#env['lilypondPath'] = '/Applications/Lilypond.app'

# on Linux
# env['musicxmlPath'] = '/usr/bin/musescore'
# env['musescoreDirectPNGPath'] = '/usr/bin/musescore'
# env['lilypondPath'] = '/usr/bin/lilypond'


print('Environment settings:')
print('musicXML:  ', env['musicxmlPath'])
print('musescore: ', env['musescoreDirectPNGPath'])
print('lilypond:  ', env['lilypondPath'])
# Out:
# Environment settings:
# musicXML:   C:\Program Files (x86)\MuseScore 2\bin\MuseScore.exe
# musescore:  C:\Program Files (x86)\MuseScore 2\bin\MuseScore.exe
# lilypond:   C:\Program Files (x86)\LilyPond\usr\bin\lilypond.exe

# %%
# routes to football-data api
apiRoot = 'http://api.football-data.org/v1'
apiWM2018Route = '/competitions/467'
apiFixtures = '/fixtures'
apiTeams = '/teams'

apiUrl_fixtures = apiRoot + apiWM2018Route + apiFixtures
apiUrl_teams = apiRoot + apiWM2018Route + apiTeams

print(apiUrl_teams)

def checkRequestStatus(request):
    "This function checks the status of an http request"
    if request.status_code == 200:
        print('HTTP request ok: ', request)
    else:
        print(request)
        print(request.status_code)
        print(request.headers)
    return
# Out:
# http://api.football-data.org/v1/competitions/467/teams

# %%
# get teams from football-data api
r1 = requests.get(apiUrl_teams)

checkRequestStatus(r1)

teamsCount = r1.json()['count']
teams = r1.json()['teams']

print('number of teams: ', teamsCount)
print(teams)
# Out:
# HTTP request ok:  <Response [200]>
# number of teams:  32
# [{'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/808'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/808/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/808/players'}}, 'name': 'Russia', 'code': 'RUS', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Russia.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/801'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/801/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/801/players'}}, 'name': 'Saudi Arabia', 'code': 'KSA', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/0/0d/Flag_of_Saudi_Arabia.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/825'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/825/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/825/players'}}, 'name': 'Egypt', 'code': 'EGY', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/f/fe/Flag_of_Egypt.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/758'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/758/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/758/players'}}, 'name': 'Uruguay', 'code': 'URU', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/f/fe/Flag_of_Uruguay.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/815'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/815/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/815/players'}}, 'name': 'Morocco', 'code': 'MAR', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/2/2c/Flag_of_Morocco.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/840'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/840/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/840/players'}}, 'name': 'Iran', 'code': 'IRN', 'shortName': 'Iran', 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/c/ca/Flag_of_Iran.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/765'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/765/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/765/players'}}, 'name': 'Portugal', 'code': 'POR', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/5/5c/Flag_of_Portugal.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/760'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/760/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/760/players'}}, 'name': 'Spain', 'code': 'ESP', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/9/9a/Flag_of_Spain.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/773'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/773/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/773/players'}}, 'name': 'France', 'code': 'FRA', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/c/c3/Flag_of_France.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/779'}, 'fixtures': {'href': 'http://api.football-data.org/v1/teams/779/fixtures'}, 'players': {'href': 'http://api.football-data.org/v1/teams/779/players'}}, 'name': 'Australia', 'code': 'AUS', 'shortName': None, 'squadMarketValue': None, 'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/b/b9/Flag_of_Australia.svg'}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/teams/7 ...

# %%
# get fixtures from football-data api
r2 = requests.get(apiUrl_fixtures)

checkRequestStatus(r2)

#store results from request
fixturesCount = r2.json()['count']
fixtures = r2.json()['fixtures']

print('number of fixtures: ', fixturesCount)
print(fixtures)
# Out:
# HTTP request ok:  <Response [200]>
# number of fixtures:  64
# [{'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165069'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/808'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/801'}}, 'date': '2018-06-14T15:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Russia', 'awayTeamName': 'Saudi Arabia', 'result': {'goalsHomeTeam': 5, 'goalsAwayTeam': 0, 'halfTime': {'goalsHomeTeam': 2, 'goalsAwayTeam': 0}}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165084'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/825'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/758'}}, 'date': '2018-06-15T12:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Egypt', 'awayTeamName': 'Uruguay', 'result': {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165083'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/815'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/840'}}, 'date': '2018-06-15T15:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Morocco', 'awayTeamName': 'Iran', 'result': {'goalsHomeTeam': 0, 'goalsAwayTeam': 1, 'halfTime': {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165076'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/765'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/760'}}, 'date': '2018-06-15T18:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Portugal', 'awayTeamName': 'Spain', 'result': {'goalsHomeTeam': 3, 'goalsAwayTeam': 3}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165072'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/773'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/779'}}, 'date': '2018-06-16T10:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'France', 'awayTeamName': 'Australia', 'result': {'goalsHomeTeam': 2, 'goalsAwayTeam': 1, 'halfTime': {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165073'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/762'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/1066'}}, 'date': '2018-06-16T13:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Argentina', 'awayTeamName': 'Iceland', 'result': {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165071'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/832'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/782'}}, 'date': '2018-06-16T16:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Peru', 'awayTeamName': 'Denmark', 'result': {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}, 'odds': None}, {'_links': {'self': {'href': 'http://api.football-data.org/v1/fixtures/165074'}, 'competition': {'href': 'http://api.football-data.org/v1/competitions/467'}, 'homeTeam': {'href': 'http://api.football-data.org/v1/teams/799'}, 'awayTeam': {'href': 'http://api.football-data.org/v1/teams/776'}}, 'date': '2018-06-16T19:00:00Z', 'status': 'FINISHED', 'matchday': 1, 'homeTeamName': 'Croatia', 'awayTeamName': 'Nigeria', 'result': {'goalsHomeTeam': 2, 'goalsAway ...

# %%
# create dictionary of groups and their resp. teams
# (API answer returns teams in order of groups)

# init variables
groupsWithTeamsDict = {}                                        # empty dictionary to populate with groups and their teams 
groupLabel = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']           # array of group labels (strings)

# function to get teams with shortcode as note object array
def getTeamsWithShortCode(teams):
    "This function returns a dictionary of (key:) team short code & (value:) an dictionary of three music21 note objects"
    teamDict = {}
    for team in teams:
        teamDict[team['code']] = {1: note.Note(), 2: note.Note(), 3: note.Note()}
    return teamDict

# get groupsWithTeamsDict
for i in range(len(groupLabel)):
    # init iteration variables to iterate over first 4 teams, then next 4 teams, etc.
    iterStart = i * 4           # 0, 4, 8, 12, etc.
    iterEnd = iterStart + 4     # 4, 8, 12, 16, etc.
    # populate groupsWithTeamsDict with groupLabel and the 4 teams for each group
    groupsWithTeamsDict[groupLabel[i]] = getTeamsWithShortCode(teams[iterStart:iterEnd])
    
print(groupsWithTeamsDict)
# Out:
# {'A': {'RUS': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KSA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'EGY': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'URU': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'B': {'MAR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'IRN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ESP': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'C': {'FRA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'AUS': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ARG': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ISL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'D': {'PER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'DEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'CRO': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'NGA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'E': {'CRC': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SRB': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'GER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'MEX': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'F': {'BRA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SUI': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SWE': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KOR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'G': {'BEL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PAN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'TUN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ENG': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'H': {'COL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'JPN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}}

# %%
def getTeamCodeFromApi(apiTeamUrl):
    r = requests.get(apiTeamUrl)
    checkRequestStatus(r)
    teamCode = r.json()['code']
    return teamCode

def getMatchShortData(fixture):
    match = {}
    homeTeamHref = fixture['_links']['homeTeam']['href']
    match['homeTeamCode'] = getTeamCodeFromApi(homeTeamHref)
    match['homeResult'] = fixture['result']['goalsHomeTeam']
    awayTeamHref = fixture['_links']['awayTeam']['href']
    match['awayTeamCode'] = getTeamCodeFromApi(awayTeamHref)
    match['awayResult'] = fixture['result']['goalsAwayTeam']
    match['matchDay'] = fixture['matchday']
    match['status'] = fixture['status']
    return match

# %%
matches = []

for fixture in fixtures:
    # take only finished matches
    if fixture['status'] == 'FINISHED':        
        matches.append(getMatchShortData(fixture))

print(matches)
# Out:
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# HTTP request ok:  <Response [200]>
# [{'homeTeamCode': 'RUS', 'homeResult': 5, 'awayTeamCode': 'KSA', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'EGY', 'homeResult': 0, 'awayTeamCode': 'URU', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'MAR', 'homeResult': 0, 'awayTeamCode': 'IRN', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'POR', 'homeResult': 3, 'awayTeamCode': 'ESP', 'awayResult': 3, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'FRA', 'homeResult': 2, 'awayTeamCode': 'AUS', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'ARG', 'homeResult': 1, 'awayTeamCode': 'ISL', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'PER', 'homeResult': 0, 'awayTeamCode': 'DEN', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'CRO', 'homeResult': 2, 'awayTeamCode': 'NGA', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'CRC', 'homeResult': 0, 'awayTeamCode': 'SRB', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'GER', 'homeResult': 0, 'awayTeamCode': 'MEX', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'BRA', 'homeResult': 1, 'awayTeamCode': 'SUI', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'SWE', 'homeResult': 1, 'awayTeamCode': 'KOR', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'BEL', 'homeResult': 3, 'awayTeamCode': 'PAN', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'TUN', 'homeResult': 1, 'awayTeamCode': 'ENG', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'COL', 'homeResult': 1, 'awayTeamCode': 'JPN', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED'}, {'homeTeamCode': 'POL', 'homeResult': 1, 'awayTeamCode': 'SEN', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED'}]

# %%
# populate groups with game results
for match in matches:
    for groupKey, groupValue in groupsWithTeamsDict.items():
        # init shortcuts
        homeCode = match['homeTeamCode']
        awayCode = match['awayTeamCode']
        matchDay = match['matchDay']
        homeResult = match['homeResult']
        awayResult = match['awayResult']        
        if homeCode and awayCode in groupValue:
            # find teamcodes in groups and add game results as pitchClasses to music21 note objects in group dictionary
            homeNote = groupValue[homeCode][matchDay]
            awayNote = groupValue[awayCode][matchDay]
            homeNote.pitch.pitchClass = homeResult
            awayNote.pitch.pitchClass = awayResult
            
            # add group label to game dictionary
            match['group'] = groupKey
            
            # transform game results to chord objects and add them to game dictionary
            separator = ': '            
            match['gameChord'] = chord.Chord([homeNote, awayNote])
            match['gameChord'].addLyric(homeCode + separator + str(homeResult))
            match['gameChord'].addLyric(awayCode + separator + str(awayResult))
            print(match)
            
print(groupsWithTeamsDict)
# Out:
# {'homeTeamCode': 'RUS', 'homeResult': 5, 'awayTeamCode': 'KSA', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED', 'group': 'A', 'gameChord': <music21.chord.Chord F4 C4>}
# {'homeTeamCode': 'EGY', 'homeResult': 0, 'awayTeamCode': 'URU', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED', 'group': 'A', 'gameChord': <music21.chord.Chord C4 C#4>}
# {'homeTeamCode': 'MAR', 'homeResult': 0, 'awayTeamCode': 'IRN', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED', 'group': 'B', 'gameChord': <music21.chord.Chord C4 C#4>}
# {'homeTeamCode': 'POR', 'homeResult': 3, 'awayTeamCode': 'ESP', 'awayResult': 3, 'matchDay': 1, 'status': 'FINISHED', 'group': 'B', 'gameChord': <music21.chord.Chord E-4 E-4>}
# {'homeTeamCode': 'FRA', 'homeResult': 2, 'awayTeamCode': 'AUS', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED', 'group': 'C', 'gameChord': <music21.chord.Chord D4 C#4>}
# {'homeTeamCode': 'ARG', 'homeResult': 1, 'awayTeamCode': 'ISL', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED', 'group': 'C', 'gameChord': <music21.chord.Chord C#4 C#4>}
# {'homeTeamCode': 'PER', 'homeResult': 0, 'awayTeamCode': 'DEN', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED', 'group': 'D', 'gameChord': <music21.chord.Chord C4 C#4>}
# {'homeTeamCode': 'CRO', 'homeResult': 2, 'awayTeamCode': 'NGA', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED', 'group': 'D', 'gameChord': <music21.chord.Chord D4 C4>}
# {'homeTeamCode': 'CRC', 'homeResult': 0, 'awayTeamCode': 'SRB', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED', 'group': 'E', 'gameChord': <music21.chord.Chord C4 C#4>}
# {'homeTeamCode': 'GER', 'homeResult': 0, 'awayTeamCode': 'MEX', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED', 'group': 'E', 'gameChord': <music21.chord.Chord C4 C#4>}
# {'homeTeamCode': 'BRA', 'homeResult': 1, 'awayTeamCode': 'SUI', 'awayResult': 1, 'matchDay': 1, 'status': 'FINISHED', 'group': 'F', 'gameChord': <music21.chord.Chord C#4 C#4>}
# {'homeTeamCode': 'SWE', 'homeResult': 1, 'awayTeamCode': 'KOR', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED', 'group': 'F', 'gameChord': <music21.chord.Chord C#4 C4>}
# {'homeTeamCode': 'BEL', 'homeResult': 3, 'awayTeamCode': 'PAN', 'awayResult': 0, 'matchDay': 1, 'status': 'FINISHED', 'group': 'G', 'gameChord': <music21.chord.Chord E-4 C4>}
# {'homeTeamCode': 'TUN', 'homeResult': 1, 'awayTeamCode': 'ENG', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED', 'group': 'G', 'gameChord': <music21.chord.Chord C#4 D4>}
# {'homeTeamCode': 'COL', 'homeResult': 1, 'awayTeamCode': 'JPN', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED', 'group': 'H', 'gameChord': <music21.chord.Chord C#4 D4>}
# {'homeTeamCode': 'POL', 'homeResult': 1, 'awayTeamCode': 'SEN', 'awayResult': 2, 'matchDay': 1, 'status': 'FINISHED', 'group': 'H', 'gameChord': <music21.chord.Chord C#4 D4>}
# {'A': {'RUS': {1: <music21.note.Note F>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KSA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'EGY': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'URU': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'B': {'MAR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'IRN': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POR': {1: <music21.note.Note E->, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ESP': {1: <music21.note.Note E->, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'C': {'FRA': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'AUS': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ARG': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ISL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'D': {'PER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'DEN': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'CRO': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'NGA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'E': {'CRC': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SRB': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'GER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'MEX': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'F': {'BRA': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SUI': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SWE': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KOR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'G': {'BEL': {1: <music21.note.Note E->, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PAN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'TUN': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ENG': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'H': {'COL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'JPN': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POL': {1: <music21.note.Note C#>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SEN': {1: <music21.note.Note D>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}}

# %%
groupChordsByMatchDay = {}

# group matches as chord pairs per matchday
for i in range(1, 4):
    matchDayChordPairsList = []
    for label in groupLabel:
        matchChordPairList = []
        for match in matches:
            if match['matchDay'] == i:                       
                if label == match['group']:
                    if 'gameChord' in match:                        
                        matchChordPairList.append(match['gameChord'])
        if matchChordPairList:
            matchDayChordPairsList.append(matchChordPairList)
    groupChordsByMatchDay[i] = matchDayChordPairsList


print(groupChordsByMatchDay)
# Out:
# {1: [[<music21.chord.Chord F4 C4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord E-4 E-4>], [<music21.chord.Chord D4 C#4>, <music21.chord.Chord C#4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord D4 C4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C#4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord E-4 C4>, <music21.chord.Chord C#4 D4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord C#4 D4>]], 2: [], 3: []}

# %%
groupStreamParts = []     # empty list as container for groups as music21 stream.Part objects


# FUNCTION: append list item to stream
def appendListItemToStream(listItem, s):
    "This function iterates over a list and appends the single items to a stream s"
    for item in listItem:
        s.append(item)
    return


# init empty group streams parts & append them to groupStreamParts
for i in range(len(groupLabel)):
    groupStreamParts.append(stream.Part())
    groupStreamParts[i].id = 'Group ' + groupLabel[i]
    groupStreamParts[i].partName = 'Group ' + groupLabel[i]


# populate groupStreamParts with groupChords
for m in range(len(groupChordsByMatchDay)):
    #iterate over matchdays
    matchDay = m + 1
    # iterate over groups 
    for i in range(len(groupStreamParts)):
        # check for 
        if i >= len(groupChordsByMatchDay[matchDay]):            
            break
        appendListItemToStream(groupChordsByMatchDay[matchDay][i], groupStreamParts[i])

            
# append all groups (stream.Parts) to final score (stream.Stream)
WMScore = stream.Stream()
appendListItemToStream(groupStreamParts, WMScore)

WMScore.show('text')
# Out:
# {0.0} <music21.stream.Part Group A>
#     {0.0} <music21.chord.Chord F4 C4>
#     {1.0} <music21.chord.Chord C4 C#4>
# {2.0} <music21.stream.Part Group B>
#     {0.0} <music21.chord.Chord C4 C#4>
#     {1.0} <music21.chord.Chord E-4 E-4>
# {4.0} <music21.stream.Part Group C>
#     {0.0} <music21.chord.Chord D4 C#4>
#     {1.0} <music21.chord.Chord C#4 C#4>
# {6.0} <music21.stream.Part Group D>
#     {0.0} <music21.chord.Chord C4 C#4>
#     {1.0} <music21.chord.Chord D4 C4>
# {8.0} <music21.stream.Part Group E>
#     {0.0} <music21.chord.Chord C4 C#4>
#     {1.0} <music21.chord.Chord C4 C#4>
# {10.0} <music21.stream.Part Group F>
#     {0.0} <music21.chord.Chord C#4 C#4>
#     {1.0} <music21.chord.Chord C#4 C4>
# {12.0} <music21.stream.Part Group G>
#     {0.0} <music21.chord.Chord E-4 C4>
#     {1.0} <music21.chord.Chord C#4 D4>
# {14.0} <music21.stream.Part Group H>
#     {0.0} <music21.chord.Chord C#4 D4>
#     {1.0} <music21.chord.Chord C#4 D4>

# %%
# add metadata
WMScore.insert(0, metadata.Metadata())
WMScore.metadata.title = '#WMScore 2018'
WMScore.metadata.composer = 'transcoded by @musicenfanthen'
WMScore.metadata.date = metadata.DateBetween(['2018/06/14','2018/06/19'])

WMScore.show('text')
# Out:
# {0.0} <music21.metadata.Metadata object at 0x1189E870>
# {0.0} <music21.stream.Part Group A>
#     {0.0} <music21.chord.Chord F4 C4>
#     {1.0} <music21.chord.Chord C4 C#4>
# {2.0} <music21.stream.Part Group B>
#     {0.0} <music21.chord.Chord C4 C#4>
#     {1.0} <music21.chord.Chord E-4 E-4>
# {4.0} <music21.stream.Part Group C>
#     {0.0} <music21.chord.Chord D4 C#4>
#     {1.0} <music21.chord.Chord C#4 C#4>
# {6.0} <music21.stream.Part Group D>
#     {0.0} <music21.chord.Chord C4 C#4>
#     {1.0} <music21.chord.Chord D4 C4>
# {8.0} <music21.stream.Part Group E>
#     {0.0} <music21.chord.Chord C4 C#4>
#     {1.0} <music21.chord.Chord C4 C#4>
# {10.0} <music21.stream.Part Group F>
#     {0.0} <music21.chord.Chord C#4 C#4>
#     {1.0} <music21.chord.Chord C#4 C4>
# {12.0} <music21.stream.Part Group G>
#     {0.0} <music21.chord.Chord E-4 C4>
#     {1.0} <music21.chord.Chord C#4 D4>
# {14.0} <music21.stream.Part Group H>
#     {0.0} <music21.chord.Chord C#4 D4>
#     {1.0} <music21.chord.Chord C#4 D4>

# %%
WMScore.show()
