# %%
################
# IMPORTS

import requests
from music21 import *

# %%
################
# ENVIRONMENT

#
# settings for correct environment paths to MuseScore & Lilypond
# 
# (comment out the parts not needed)
#

env = environment.Environment()
# env['musicxmlPath'] = 'path/to/your/musicXmlApplication'
# env['musescoreDirectPNGPath'] = 'path/to/your/museScore'
# env['lilypondPath'] = path/to/your/lilypond'

# on WIN:
env['musicxmlPath'] = 'C:/Program Files (x86)/MuseScore 2/bin/MuseScore.exe'
env['musescoreDirectPNGPath'] = 'C:/Program Files (x86)/MuseScore 2/bin/MuseScore.exe'
env['lilypondPath'] = 'C:/Program Files (x86)/LilyPond/usr/bin/lilypond.exe'

# on Mac:
#env['musicxmlPath'] = '/Applications/MuseScore 2.app/Contents/MacOS/mscore'
#env['musescoreDirectPNGPath'] = '/Applications/MuseScore 2.app/Contents/MacOS/mscore'
#env['lilypondPath'] = '/Applications/Lilypond.app'

# on Linux:
# env['musicxmlPath'] = '/usr/bin/musescore'
# env['musescoreDirectPNGPath'] = '/usr/bin/musescore'
# env['lilypondPath'] = '/usr/bin/lilypond'


print('Environment settings:')
print('musicXML:  ', env['musicxmlPath'])
print('musescore: ', env['musescoreDirectPNGPath'])
print('lilypond:  ', env['lilypondPath'])
# Out:
# Environment settings:
# musicXML:   C:\Program Files (x86)\MuseScore 2\bin\MuseScore.exe
# musescore:  C:\Program Files (x86)\MuseScore 2\bin\MuseScore.exe
# lilypond:   C:\Program Files (x86)\LilyPond\usr\bin\lilypond.exe

# %%
################
# INIT

# routes to football-data api
apiRoot = 'http://api.football-data.org/v1'
apiWM2018Route = '/competitions/467'
apiFixtures = '/fixtures'
apiTeams = '/teams'

apiUrl_fixtures = apiRoot + apiWM2018Route + apiFixtures
apiUrl_teams = apiRoot + apiWM2018Route + apiTeams

print(apiUrl_fixtures)
print(apiUrl_teams)
# Out:
# http://api.football-data.org/v1/competitions/467/fixtures
# http://api.football-data.org/v1/competitions/467/teams

# %%
################
# FUNCTIONS


# FUNCTION to check the status of an http request
def checkRequestStatus(request):
    "This function checks the status of an http request and prints further information for failing requests"
    if not request.status_code == 200:
        print(request)
        print(request.status_code)
        print(request.headers)
    return


# FUNCTION to create note object dictionaries per team
def createNoteObjectsPerTeam(teamNoteObject):
    "This function returns a dictionary of 3 music21 note objects"
    teamNoteObject =  {1: note.Note(), 2: note.Note(), 3: note.Note()}
    return teamNoteObject


# FUNCTION to get the shortcode of a team
# teamHref: 'http://api.football-data.org/v1/teams/XXX' with XXX: 3-digit team id
def getTeamCodeFromApi(teamHref):
    "This function returns the shortcode of a team"
    for team in teams:
        if (teamHref == team['_links']['self']['href']):
            return team['code']

        
# FUNCTION go get data about a single match
def getMatchShortData(fixture):
    "This function returns a dictionary with compacted data about a single match, including homeTeamCode, homeResult, awayTeamCode, awayResult, status & matchDay"
    match = {}
    resultObj = {}
    homeTeamHref = fixture['_links']['homeTeam']['href']
    match['homeTeamCode'] = getTeamCodeFromApi(homeTeamHref)
    awayTeamHref = fixture['_links']['awayTeam']['href']
    match['awayTeamCode'] = getTeamCodeFromApi(awayTeamHref)
    match['matchDay'] = fixture['matchday']
    match['status'] = fixture['status']
    if ('penaltyShootout' in fixture['result']):
        resultObj = fixture['result']['penaltyShootout']
        match['addition'] = 'n. E.'
    elif ('extraTime' in fixture['result']):
        resultObj = fixture['result']['extraTime']
        match['addition'] = 'n. V.'
    else:
        resultObj = fixture['result']
    match['homeResult'] = resultObj['goalsHomeTeam']
    match['awayResult'] = resultObj['goalsAwayTeam']  
    
    return match


# FUNCTION to append list items to a stream
def appendListItemToStream(listItem, s):
    "This function iterates over a list and appends the single items to a stream s"
    for item in listItem:
        s.append(item)
    return

# %%
################
# HTTP REQUESTS

# HTTP request 1: get teams from football-data api
r1 = requests.get(apiUrl_teams)
checkRequestStatus(r1)

#store results from request
teamsCount = r1.json()['count']
teams = r1.json()['teams']

print('number of teams: ', teamsCount)
print(teams)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\www\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# c:\www\python\python36\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      55
# ---> 56     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      57         af, socktype, proto, canonname, sa = res
#
# c:\www\python\python36\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\www\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\www\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# c:\www\python\python36\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# c:\www\python\python36\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# c:\www\python\python36\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# c:\www\python\python36\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# c:\www\python\python36\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# c:\www\python\python36\lib\site-packages\urllib3\connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# c:\www\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x1105F4D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\www\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# c:\www\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# c:\www\python\python36\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='api.football-data.org', port=80): Max retries exceeded with url: /v1/competitions/467/teams (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1105F4D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-faf077343542> in <module>()
#       3
#       4 # HTTP request 1: get teams from football-data api
# ----> 5 r1 = requests.get(apiUrl_teams)
#       6 checkRequestStatus(r1)
#       7
#
# c:\www\python\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\www\python\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\www\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# c:\www\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# c:\www\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     511                 raise SSLError(e, request=request)
#     512
# --> 513             raise ConnectionError(e, request=request)
#     514
#     515         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='api.football-data.org', port=80): Max retries exceeded with url: /v1/competitions/467/teams (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1105F4D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))

# %%
# # HTTP request 2: get fixtures from football-data api
r2 = requests.get(apiUrl_fixtures)
checkRequestStatus(r2)

#store results from request
fixturesCount = r2.json()['count']
fixtures = r2.json()['fixtures']

print('number of fixtures: ', fixturesCount)
print(fixtures)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\www\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# c:\www\python\python36\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      55
# ---> 56     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      57         af, socktype, proto, canonname, sa = res
#
# c:\www\python\python36\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\www\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\www\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# c:\www\python\python36\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# c:\www\python\python36\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# c:\www\python\python36\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# c:\www\python\python36\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# c:\www\python\python36\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# c:\www\python\python36\lib\site-packages\urllib3\connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# c:\www\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x1116FAB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\www\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# c:\www\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# c:\www\python\python36\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='api.football-data.org', port=80): Max retries exceeded with url: /v1/competitions/467/fixtures (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1116FAB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-8-3422c5581b77> in <module>()
#       1 # # HTTP request 2: get fixtures from football-data api
# ----> 2 r2 = requests.get(apiUrl_fixtures)
#       3 checkRequestStatus(r2)
#       4
#       5 #store results from request
#
# c:\www\python\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\www\python\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\www\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# c:\www\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# c:\www\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     511                 raise SSLError(e, request=request)
#     512
# --> 513             raise ConnectionError(e, request=request)
#     514
#     515         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='api.football-data.org', port=80): Max retries exceeded with url: /v1/competitions/467/fixtures (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1116FAB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))

# %%
# create dictionary of groups and their resp. teams
  
# init variables
groupsWithTeamsDict = {}                                        # empty dictionary to populate with groups and their teams 
groupLabel = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']           # array of group labels (strings)
groupsDict = [                                                  # API returns no group infos, so it has to be added manually   
    {'RUS': {}, 'KSA': {}, 'EGY': {}, 'URU': {}},
    {'MAR': {}, 'IRN': {}, 'ESP': {}, 'POR': {}},
    {'FRA': {}, 'DEN': {}, 'AUS': {}, 'PER': {}},
    {'CRO': {}, 'NGA': {}, 'ISL': {}, 'ARG': {}},
    {'BRA': {}, 'SUI': {}, 'CRC': {}, 'SRB': {}},
    {'GER': {}, 'MEX': {}, 'SWE': {}, 'KOR': {}},
    {'BEL': {}, 'PAN': {}, 'TUN': {}, 'ENG': {}},
    {'COL': {}, 'JPN': {}, 'POL': {}, 'SEN': {}}
]                      


# create dictionary
if (len(groupLabel) == len(groupsDict)):
    for i in range(len(groupLabel)):
        # iterate over teams per group
        for teamCode, teamNoteObject in groupsDict[i].items():
            # create note object for every single team
            groupsDict[i][teamCode] = createNoteObjectsPerTeam(teamNoteObject)  
        # populate groupsWithTeamsDict with groupLabel and the 4 teams for each group
        groupsWithTeamsDict[groupLabel[i]] = groupsDict[i]
        

print(groupsWithTeamsDict)
# Out:
# {'A': {'RUS': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KSA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'EGY': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'URU': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'B': {'MAR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'IRN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ESP': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'C': {'FRA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'DEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'AUS': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'D': {'CRO': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'NGA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ISL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ARG': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'E': {'BRA': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SUI': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'CRC': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SRB': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'F': {'GER': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'MEX': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SWE': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'KOR': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'G': {'BEL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'PAN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'TUN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'ENG': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}, 'H': {'COL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'JPN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'POL': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}, 'SEN': {1: <music21.note.Note C>, 2: <music21.note.Note C>, 3: <music21.note.Note C>}}}

# %%
# create list of matches and their resp. data

# init
matches = []

# get matchdata for finished matches
for fixture in fixtures:
    # consider only finished matches
    if fixture['status'] == 'FINISHED': 
        # get compact data about match 
        matches.append(getMatchShortData(fixture))

print(matches)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5a8e4b307919> in <module>()
#       5
#       6 # get matchdata for finished matches
# ----> 7 for fixture in fixtures:
#       8     # consider only finished matches
#       9     if fixture['status'] == 'FINISHED':
#
# NameError: name 'fixtures' is not defined

# %%
# populate match results

# iterate over matches
for match in matches:
    # init shortcuts
    homeCode = match['homeTeamCode']
    awayCode = match['awayTeamCode']
    matchDay = match['matchDay']
    homeResult = match['homeResult']
    awayResult = match['awayResult']

    # add match results as pitchClasses to music21 note objects
    noteLength = 'quarter'
    if (match['matchDay'] > 3):
        noteLength = 'half'
    homeNote = note.Note(type=noteLength)
    awayNote = note.Note(type=noteLength)
    homeNote.pitch.pitchClass = homeResult
    awayNote.pitch.pitchClass = awayResult

    # transform match results to chord objects with result strings as lyrics and add them all to match dictionary
    separator = ': '            
    match['gameChord'] = chord.Chord([homeNote, awayNote])
    match['gameChord'].addLyric(homeCode + separator + str(homeResult))
    match['gameChord'].addLyric(awayCode + separator + str(awayResult))
    if ('addition' in match):
        match['gameChord'].addLyric(match['addition'])
    
    # iterate over groups
    for groupKey, groupValue in groupsWithTeamsDict.items():
        # find teamcodes in groups 
        if homeCode in groupValue:
             # add group label to match dictionary
            match['homeTeamGroup'] = groupKey
        if awayCode in groupValue:
             # add group label to match dictionary
            match['awayTeamGroup'] = groupKey
        
    print('match: ', match)
# Out:
# match:  {'homeTeamCode': 'RUS', 'awayTeamCode': 'KSA', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 5, 'awayResult': 0, 'group': 'A', 'gameChord': <music21.chord.Chord F4 C4>, 'homeTeamGroup': 'A', 'awayTeamGroup': 'A'}
# match:  {'homeTeamCode': 'EGY', 'awayTeamCode': 'URU', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 1, 'group': 'A', 'gameChord': <music21.chord.Chord C4 C#4>, 'homeTeamGroup': 'A', 'awayTeamGroup': 'A'}
# match:  {'homeTeamCode': 'MAR', 'awayTeamCode': 'IRN', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 1, 'group': 'B', 'gameChord': <music21.chord.Chord C4 C#4>, 'homeTeamGroup': 'B', 'awayTeamGroup': 'B'}
# match:  {'homeTeamCode': 'POR', 'awayTeamCode': 'ESP', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 3, 'awayResult': 3, 'group': 'B', 'gameChord': <music21.chord.Chord E-4 E-4>, 'homeTeamGroup': 'B', 'awayTeamGroup': 'B'}
# match:  {'homeTeamCode': 'FRA', 'awayTeamCode': 'AUS', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 1, 'group': 'C', 'gameChord': <music21.chord.Chord D4 C#4>, 'homeTeamGroup': 'C', 'awayTeamGroup': 'C'}
# match:  {'homeTeamCode': 'ARG', 'awayTeamCode': 'ISL', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 1, 'group': 'D', 'gameChord': <music21.chord.Chord C#4 C#4>, 'homeTeamGroup': 'D', 'awayTeamGroup': 'D'}
# match:  {'homeTeamCode': 'PER', 'awayTeamCode': 'DEN', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 1, 'group': 'C', 'gameChord': <music21.chord.Chord C4 C#4>, 'homeTeamGroup': 'C', 'awayTeamGroup': 'C'}
# match:  {'homeTeamCode': 'CRO', 'awayTeamCode': 'NGA', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0, 'group': 'D', 'gameChord': <music21.chord.Chord D4 C4>, 'homeTeamGroup': 'D', 'awayTeamGroup': 'D'}
# match:  {'homeTeamCode': 'CRC', 'awayTeamCode': 'SRB', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 1, 'group': 'E', 'gameChord': <music21.chord.Chord C4 C#4>, 'homeTeamGroup': 'E', 'awayTeamGroup': 'E'}
# match:  {'homeTeamCode': 'GER', 'awayTeamCode': 'MEX', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 1, 'group': 'F', 'gameChord': <music21.chord.Chord C4 C#4>, 'homeTeamGroup': 'F', 'awayTeamGroup': 'F'}
# match:  {'homeTeamCode': 'BRA', 'awayTeamCode': 'SUI', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 1, 'group': 'E', 'gameChord': <music21.chord.Chord C#4 C#4>, 'homeTeamGroup': 'E', 'awayTeamGroup': 'E'}
# match:  {'homeTeamCode': 'SWE', 'awayTeamCode': 'KOR', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0, 'group': 'F', 'gameChord': <music21.chord.Chord C#4 C4>, 'homeTeamGroup': 'F', 'awayTeamGroup': 'F'}
# match:  {'homeTeamCode': 'BEL', 'awayTeamCode': 'PAN', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 3, 'awayResult': 0, 'group': 'G', 'gameChord': <music21.chord.Chord E-4 C4>, 'homeTeamGroup': 'G', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'TUN', 'awayTeamCode': 'ENG', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'group': 'G', 'gameChord': <music21.chord.Chord C#4 D4>, 'homeTeamGroup': 'G', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'COL', 'awayTeamCode': 'JPN', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'group': 'H', 'gameChord': <music21.chord.Chord C#4 D4>, 'homeTeamGroup': 'H', 'awayTeamGroup': 'H'}
# match:  {'homeTeamCode': 'POL', 'awayTeamCode': 'SEN', 'matchDay': 1, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'group': 'H', 'gameChord': <music21.chord.Chord C#4 D4>, 'homeTeamGroup': 'H', 'awayTeamGroup': 'H'}
# match:  {'homeTeamCode': 'RUS', 'awayTeamCode': 'EGY', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 3, 'awayResult': 1, 'group': 'A', 'gameChord': <music21.chord.Chord E-4 C#4>, 'homeTeamGroup': 'A', 'awayTeamGroup': 'A'}
# match:  {'homeTeamCode': 'POR', 'awayTeamCode': 'MAR', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0, 'group': 'B', 'gameChord': <music21.chord.Chord C#4 C4>, 'homeTeamGroup': 'B', 'awayTeamGroup': 'B'}
# match:  {'homeTeamCode': 'URU', 'awayTeamCode': 'KSA', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0, 'group': 'A', 'gameChord': <music21.chord.Chord C#4 C4>, 'homeTeamGroup': 'A', 'awayTeamGroup': 'A'}
# match:  {'homeTeamCode': 'IRN', 'awayTeamCode': 'ESP', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 1, 'group': 'B', 'gameChord': <music21.chord.Chord C4 C#4>, 'homeTeamGroup': 'B', 'awayTeamGroup': 'B'}
# match:  {'homeTeamCode': 'DEN', 'awayTeamCode': 'AUS', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 1, 'group': 'C', 'gameChord': <music21.chord.Chord C#4 C#4>, 'homeTeamGroup': 'C', 'awayTeamGroup': 'C'}
# match:  {'homeTeamCode': 'FRA', 'awayTeamCode': 'PER', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0, 'group': 'C', 'gameChord': <music21.chord.Chord C#4 C4>, 'homeTeamGroup': 'C', 'awayTeamGroup': 'C'}
# match:  {'homeTeamCode': 'ARG', 'awayTeamCode': 'CRO', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 3, 'group': 'D', 'gameChord': <music21.chord.Chord C4 E-4>, 'homeTeamGroup': 'D', 'awayTeamGroup': 'D'}
# match:  {'homeTeamCode': 'BRA', 'awayTeamCode': 'CRC', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0, 'group': 'E', 'gameChord': <music21.chord.Chord D4 C4>, 'homeTeamGroup': 'E', 'awayTeamGroup': 'E'}
# match:  {'homeTeamCode': 'NGA', 'awayTeamCode': 'ISL', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0, 'group': 'D', 'gameChord': <music21.chord.Chord D4 C4>, 'homeTeamGroup': 'D', 'awayTeamGroup': 'D'}
# match:  {'homeTeamCode': 'SRB', 'awayTeamCode': 'SUI', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'group': 'E', 'gameChord': <music21.chord.Chord C#4 D4>, 'homeTeamGroup': 'E', 'awayTeamGroup': 'E'}
# match:  {'homeTeamCode': 'BEL', 'awayTeamCode': 'TUN', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 5, 'awayResult': 2, 'group': 'G', 'gameChord': <music21.chord.Chord F4 D4>, 'homeTeamGroup': 'G', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'KOR', 'awayTeamCode': 'MEX', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'group': 'F', 'gameChord': <music21.chord.Chord C#4 D4>, 'homeTeamGroup': 'F', 'awayTeamGroup': 'F'}
# match:  {'homeTeamCode': 'GER', 'awayTeamCode': 'SWE', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 1, 'group': 'F', 'gameChord': <music21.chord.Chord D4 C#4>, 'homeTeamGroup': 'F', 'awayTeamGroup': 'F'}
# match:  {'homeTeamCode': 'ENG', 'awayTeamCode': 'PAN', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 6, 'awayResult': 1, 'group': 'G', 'gameChord': <music21.chord.Chord F#4 C#4>, 'homeTeamGroup': 'G', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'JPN', 'awayTeamCode': 'SEN', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 2, 'group': 'H', 'gameChord': <music21.chord.Chord D4 D4>, 'homeTeamGroup': 'H', 'awayTeamGroup': 'H'}
# match:  {'homeTeamCode': 'POL', 'awayTeamCode': 'COL', 'matchDay': 2, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 3, 'group': 'H', 'gameChord': <music21.chord.Chord C4 E-4>, 'homeTeamGroup': 'H', 'awayTeamGroup': 'H'}
# match:  {'homeTeamCode': 'KSA', 'awayTeamCode': 'EGY', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 1, 'group': 'A', 'gameChord': <music21.chord.Chord D4 C#4>, 'homeTeamGroup': 'A', 'awayTeamGroup': 'A'}
# match:  {'homeTeamCode': 'URU', 'awayTeamCode': 'RUS', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 3, 'awayResult': 0, 'group': 'A', 'gameChord': <music21.chord.Chord E-4 C4>, 'homeTeamGroup': 'A', 'awayTeamGroup': 'A'}
# match:  {'homeTeamCode': 'IRN', 'awayTeamCode': 'POR', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 1, 'group': 'B', 'gameChord': <music21.chord.Chord C#4 C#4>, 'homeTeamGroup': 'B', 'awayTeamGroup': 'B'}
# match:  {'homeTeamCode': 'ESP', 'awayTeamCode': 'MAR', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 2, 'group': 'B', 'gameChord': <music21.chord.Chord D4 D4>, 'homeTeamGroup': 'B', 'awayTeamGroup': 'B'}
# match:  {'homeTeamCode': 'DEN', 'awayTeamCode': 'FRA', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 0, 'group': 'C', 'gameChord': <music21.chord.Chord C4 C4>, 'homeTeamGroup': 'C', 'awayTeamGroup': 'C'}
# match:  {'homeTeamCode': 'AUS', 'awayTeamCode': 'PER', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 2, 'group': 'C', 'gameChord': <music21.chord.Chord C4 D4>, 'homeTeamGroup': 'C', 'awayTeamGroup': 'C'}
# match:  {'homeTeamCode': 'NGA', 'awayTeamCode': 'ARG', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'group': 'D', 'gameChord': <music21.chord.Chord C#4 D4>, 'homeTeamGroup': 'D', 'awayTeamGroup': 'D'}
# match:  {'homeTeamCode': 'ISL', 'awayTeamCode': 'CRO', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'group': 'D', 'gameChord': <music21.chord.Chord C#4 D4>, 'homeTeamGroup': 'D', 'awayTeamGroup': 'D'}
# match:  {'homeTeamCode': 'MEX', 'awayTeamCode': 'SWE', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 3, 'group': 'F', 'gameChord': <music21.chord.Chord C4 E-4>, 'homeTeamGroup': 'F', 'awayTeamGroup': 'F'}
# match:  {'homeTeamCode': 'KOR', 'awayTeamCode': 'GER', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0, 'group': 'F', 'gameChord': <music21.chord.Chord D4 C4>, 'homeTeamGroup': 'F', 'awayTeamGroup': 'F'}
# match:  {'homeTeamCode': 'SRB', 'awayTeamCode': 'BRA', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 2, 'group': 'E', 'gameChord': <music21.chord.Chord C4 D4>, 'homeTeamGroup': 'E', 'awayTeamGroup': 'E'}
# match:  {'homeTeamCode': 'SUI', 'awayTeamCode': 'CRC', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 2, 'group': 'E', 'gameChord': <music21.chord.Chord D4 D4>, 'homeTeamGroup': 'E', 'awayTeamGroup': 'E'}
# match:  {'homeTeamCode': 'JPN', 'awayTeamCode': 'POL', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 1, 'group': 'H', 'gameChord': <music21.chord.Chord C4 C#4>, 'homeTeamGroup': 'H', 'awayTeamGroup': 'H'}
# match:  {'homeTeamCode': 'SEN', 'awayTeamCode': 'COL', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 1, 'group': 'H', 'gameChord': <music21.chord.Chord C4 C#4>, 'homeTeamGroup': 'H', 'awayTeamGroup': 'H'}
# match:  {'homeTeamCode': 'PAN', 'awayTeamCode': 'TUN', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'group': 'G', 'gameChord': <music21.chord.Chord C#4 D4>, 'homeTeamGroup': 'G', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'ENG', 'awayTeamCode': 'BEL', 'matchDay': 3, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 1, 'group': 'G', 'gameChord': <music21.chord.Chord C4 C#4>, 'homeTeamGroup': 'G', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'FRA', 'awayTeamCode': 'ARG', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 4, 'awayResult': 3, 'gameChord': <music21.chord.Chord E4 E-4>, 'group': 'D', 'homeTeamGroup': 'C', 'awayTeamGroup': 'D'}
# match:  {'homeTeamCode': 'URU', 'awayTeamCode': 'POR', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 1, 'gameChord': <music21.chord.Chord D4 C#4>, 'group': 'B', 'homeTeamGroup': 'A', 'awayTeamGroup': 'B'}
# match:  {'homeTeamCode': 'ESP', 'awayTeamCode': 'RUS', 'matchDay': 4, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 4, 'gameChord': <music21.chord.Chord E-4 E4>, 'group': 'A', 'awayTeamGroup': 'A', 'homeTeamGroup': 'B'}
# match:  {'homeTeamCode': 'CRO', 'awayTeamCode': 'DEN', 'matchDay': 4, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 2, 'gameChord': <music21.chord.Chord E-4 D4>, 'group': 'C', 'awayTeamGroup': 'C', 'homeTeamGroup': 'D'}
# match:  {'homeTeamCode': 'BRA', 'awayTeamCode': 'MEX', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0, 'gameChord': <music21.chord.Chord D4 C4>, 'group': 'F', 'homeTeamGroup': 'E', 'awayTeamGroup': 'F'}
# match:  {'homeTeamCode': 'BEL', 'awayTeamCode': 'JPN', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 3, 'awayResult': 2, 'gameChord': <music21.chord.Chord E-4 D4>, 'group': 'H', 'homeTeamGroup': 'G', 'awayTeamGroup': 'H'}
# match:  {'homeTeamCode': 'SWE', 'awayTeamCode': 'SUI', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0, 'gameChord': <music21.chord.Chord C#4 C4>, 'group': 'E', 'awayTeamGroup': 'E', 'homeTeamGroup': 'F'}
# match:  {'homeTeamCode': 'COL', 'awayTeamCode': 'ENG', 'matchDay': 4, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 4, 'gameChord': <music21.chord.Chord E-4 E4>, 'group': 'G', 'awayTeamGroup': 'G', 'homeTeamGroup': 'H'}
# match:  {'homeTeamCode': 'URU', 'awayTeamCode': 'FRA', 'matchDay': 5, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 2, 'gameChord': <music21.chord.Chord C4 D4>, 'group': 'C', 'homeTeamGroup': 'A', 'awayTeamGroup': 'C'}
# match:  {'homeTeamCode': 'BRA', 'awayTeamCode': 'BEL', 'matchDay': 5, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'gameChord': <music21.chord.Chord C#4 D4>, 'group': 'G', 'homeTeamGroup': 'E', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'SWE', 'awayTeamCode': 'ENG', 'matchDay': 5, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 2, 'gameChord': <music21.chord.Chord C4 D4>, 'group': 'G', 'homeTeamGroup': 'F', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'RUS', 'awayTeamCode': 'CRO', 'matchDay': 5, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 4, 'gameChord': <music21.chord.Chord E-4 E4>, 'group': 'D', 'homeTeamGroup': 'A', 'awayTeamGroup': 'D'}
# match:  {'homeTeamCode': 'FRA', 'awayTeamCode': 'BEL', 'matchDay': 6, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0, 'gameChord': <music21.chord.Chord C#4 C4>, 'group': 'G', 'homeTeamGroup': 'C', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'CRO', 'awayTeamCode': 'ENG', 'matchDay': 6, 'status': 'FINISHED', 'addition': 'n. V.', 'homeResult': 2, 'awayResult': 1, 'gameChord': <music21.chord.Chord D4 C#4>, 'group': 'G', 'homeTeamGroup': 'D', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'BEL', 'awayTeamCode': 'ENG', 'matchDay': 7, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0, 'gameChord': <music21.chord.Chord D4 C4>, 'group': 'G', 'homeTeamGroup': 'G', 'awayTeamGroup': 'G'}
# match:  {'homeTeamCode': 'FRA', 'awayTeamCode': 'CRO', 'matchDay': 8, 'status': 'FINISHED', 'homeResult': 4, 'awayResult': 2, 'gameChord': <music21.chord.Chord E4 D4>, 'group': 'D', 'homeTeamGroup': 'C', 'awayTeamGroup': 'D'}

# %%
# group matches as chord pairs per matchday

# init
groupChordsByMatchDay = {}

# get matchDays with group matches as chord pairs
for i in range(1, 9):
    # iterate over matchDays 1-8 (group phase + knockout phase)
    matchDayChordPairsList = []

    for label in groupLabel:
        # iterate over group label (A-H)
        matchChordPairList = []
        for match in matches:
            # iterate over matches and check for correct matchday and group
            if match['matchDay'] == i:
                if match['homeTeamGroup'] == label:
                    if 'gameChord' in match:
                        # add existing chords to pair list
                        matchChordPairList.append(match['gameChord'])
        if matchChordPairList:
            # add existing pair lists to matchday
            matchDayChordPairsList.append(matchChordPairList)
    
    # check for two values per group array after quarter finals (matchday > 4)
    if i > 4:
        for pairIndex, pair in enumerate(matchDayChordPairsList):
            # iterate over pair list with index
            if (len(pair) > 1):
                # extract second value from array
                extractedChord = pair.pop()
                # insert extracted value as separate array to pair list
                matchDayChordPairsList.insert(pairIndex+1, [extractedChord])
    
    # populate dictionary with matchdays and their resp. pair lists
    groupChordsByMatchDay[i] = matchDayChordPairsList


print(groupChordsByMatchDay)
# Out:
# {1: [[<music21.chord.Chord F4 C4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord E-4 E-4>], [<music21.chord.Chord D4 C#4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C#4 C#4>, <music21.chord.Chord D4 C4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord C#4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord E-4 C4>, <music21.chord.Chord C#4 D4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord C#4 D4>]], 2: [[<music21.chord.Chord E-4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord C#4 C4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C#4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord C4 E-4>, <music21.chord.Chord D4 C4>], [<music21.chord.Chord D4 C4>, <music21.chord.Chord C#4 D4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord D4 C#4>], [<music21.chord.Chord F4 D4>, <music21.chord.Chord F#4 C#4>], [<music21.chord.Chord D4 D4>, <music21.chord.Chord C4 E-4>]], 3: [[<music21.chord.Chord D4 C#4>, <music21.chord.Chord E-4 C4>], [<music21.chord.Chord C#4 C#4>, <music21.chord.Chord D4 D4>], [<music21.chord.Chord C4 C4>, <music21.chord.Chord C4 D4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord C#4 D4>], [<music21.chord.Chord C4 D4>, <music21.chord.Chord D4 D4>], [<music21.chord.Chord C4 E-4>, <music21.chord.Chord D4 C4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord C4 C#4>]], 4: [[<music21.chord.Chord D4 C#4>], [<music21.chord.Chord E-4 E4>], [<music21.chord.Chord E4 E-4>], [<music21.chord.Chord E-4 D4>], [<music21.chord.Chord D4 C4>], [<music21.chord.Chord C#4 C4>], [<music21.chord.Chord E-4 D4>], [<music21.chord.Chord E-4 E4>]], 5: [[<music21.chord.Chord C4 D4>], [<music21.chord.Chord E-4 E4>], [<music21.chord.Chord C#4 D4>], [<music21.chord.Chord C4 D4>]], 6: [[<music21.chord.Chord C#4 C4>], [<music21.chord.Chord D4 C#4>]], 7: [[<music21.chord.Chord D4 C4>]], 8: [[<music21.chord.Chord E4 D4>]]}

# %%
# add rests for empty game lines
for matchDay, groupChordPairs in groupChordsByMatchDay.items():
    
    restLength = 'half'
    
    if matchDay == 5:
        for i in range(0, 4):
            groupChordPairs.insert(2*i+1, [note.Rest(type=restLength)])
            
    
    if matchDay == 6:
        for i in range(0, 2):
            groupChordPairs.insert(i, [note.Rest(type=restLength)])
            groupChordPairs.append([note.Rest(type=restLength)])
        groupChordPairs.insert(3, [note.Rest(type=restLength)])
        groupChordPairs.append([note.Rest(type=restLength)])
        print(groupChordPairs)
        
    if matchDay == 7:
        for i in range(0, 3):
            groupChordPairs.insert(i, [note.Rest(type=restLength)])
            groupChordPairs.append([note.Rest(type=restLength)])
        groupChordPairs.append([note.Rest(type=restLength)])
        print(groupChordPairs)
    
    if matchDay == 8:
        for i in range(0, 3):
            groupChordPairs.insert(i, [note.Rest(type=restLength)])
            groupChordPairs.append([note.Rest(type=restLength)])
        groupChordPairs.append([note.Rest(type=restLength)])
        print(groupChordPairs)
    
print(groupChordsByMatchDay)
# Out:
# [[<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.chord.Chord C#4 C4>], [<music21.note.Rest rest>], [<music21.chord.Chord D4 C#4>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>]]
# [[<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.chord.Chord D4 C4>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>]]
# [[<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.chord.Chord E4 D4>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>]]
# {1: [[<music21.chord.Chord F4 C4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord E-4 E-4>], [<music21.chord.Chord D4 C#4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C#4 C#4>, <music21.chord.Chord D4 C4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord C#4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord E-4 C4>, <music21.chord.Chord C#4 D4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord C#4 D4>]], 2: [[<music21.chord.Chord E-4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord C#4 C4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C#4 C#4>, <music21.chord.Chord C#4 C4>], [<music21.chord.Chord C4 E-4>, <music21.chord.Chord D4 C4>], [<music21.chord.Chord D4 C4>, <music21.chord.Chord C#4 D4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord D4 C#4>], [<music21.chord.Chord F4 D4>, <music21.chord.Chord F#4 C#4>], [<music21.chord.Chord D4 D4>, <music21.chord.Chord C4 E-4>]], 3: [[<music21.chord.Chord D4 C#4>, <music21.chord.Chord E-4 C4>], [<music21.chord.Chord C#4 C#4>, <music21.chord.Chord D4 D4>], [<music21.chord.Chord C4 C4>, <music21.chord.Chord C4 D4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord C#4 D4>], [<music21.chord.Chord C4 D4>, <music21.chord.Chord D4 D4>], [<music21.chord.Chord C4 E-4>, <music21.chord.Chord D4 C4>], [<music21.chord.Chord C#4 D4>, <music21.chord.Chord C4 C#4>], [<music21.chord.Chord C4 C#4>, <music21.chord.Chord C4 C#4>]], 4: [[<music21.chord.Chord D4 C#4>], [<music21.chord.Chord E-4 E4>], [<music21.chord.Chord E4 E-4>], [<music21.chord.Chord E-4 D4>], [<music21.chord.Chord D4 C4>], [<music21.chord.Chord C#4 C4>], [<music21.chord.Chord E-4 D4>], [<music21.chord.Chord E-4 E4>]], 5: [[<music21.chord.Chord C4 D4>], [<music21.note.Rest rest>], [<music21.chord.Chord E-4 E4>], [<music21.note.Rest rest>], [<music21.chord.Chord C#4 D4>], [<music21.note.Rest rest>], [<music21.chord.Chord C4 D4>], [<music21.note.Rest rest>]], 6: [[<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.chord.Chord C#4 C4>], [<music21.note.Rest rest>], [<music21.chord.Chord D4 C#4>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>]], 7: [[<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.chord.Chord D4 C4>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>]], 8: [[<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.chord.Chord E4 D4>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>], [<music21.note.Rest rest>]]}

# %%
# create final WMScore stream

# init
groupStreamParts = []     # empty list as container for groups as music21 stream.Part objects


# init empty parts (stream.Part) for every group
for i in range(len(groupLabel)):
    groupString = 'Group ' + groupLabel[i]
    groupStreamParts.append(stream.Part(id=groupString))
    groupStreamParts[i].partName = groupString    
    

# populate groupStreamParts with groupChords
# iterate over matchdays
for matchDay, groupChordPairs in groupChordsByMatchDay.items():
    
    # iterate over groupChordPairs of a matchday
    for i in range(len(groupChordPairs)):
        
        # create music21 measure object with matchday as number
        matchDayMeasure = stream.Measure(number=matchDay)
        
        # iterate over every chord of a chordPair and append it to matchday measure
        for k in range(len(groupChordPairs[i])):
            matchDayMeasure.append(groupChordPairs[i][k])
            
        # check for match of i with length of part list
        if i >= len(groupStreamParts):            
            break
        # append matchday measure to resp. part stream
        groupStreamParts[i].append(matchDayMeasure)
        
        if matchDay > 5:
            groupStreamParts[i].show()

    print('**************')
            
# create final WMScore stream object (stream.Stream)
WMScore = stream.Stream(id='WMScore')

# append all groups (stream.Parts) to final WMScore (stream.Stream)
appendListItemToStream(groupStreamParts, WMScore)

WMScore.show('text')
# Out:
# **************
# **************
# **************
# **************
# **************
# **************
# **************
# **************
# {0.0} <music21.stream.Part Group A>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord F4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord E-4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#         {1.0} <music21.chord.Chord E-4 C4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord C4 D4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {16.0} <music21.stream.Part Group B>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord E-4 E-4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord D4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 E4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {32.0} <music21.stream.Part Group C>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 C4>
#         {1.0} <music21.chord.Chord C4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E4 E-4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord E-4 E4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {48.0} <music21.stream.Part Group D>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C4 E-4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 D4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.chord.Chord D4 C4>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.chord.Chord E4 D4>
# {64.0} <music21.stream.Part Group E>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 D4>
#         {1.0} <music21.chord.Chord D4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord D4 C4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {80.0} <music21.stream.Part Group F>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord D4 C#4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 E-4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {96.0} <music21.stream.Part Group G>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord E-4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord F4 D4>
#         {1.0} <music21.chord.Chord F#4 C#4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 D4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord C4 D4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {112.0} <music21.stream.Part Group H>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 D4>
#         {1.0} <music21.chord.Chord C4 E-4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 E4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>

# %%
################
# METADATA

WMScore.insert(0.0, metadata.Metadata())
WMScore.metadata.title = '#WMScore 2018'
WMScore.metadata.composer = 'transcoded by @musicenfanthen'
WMScore.metadata.date = metadata.DateBetween(['2018/06/14','2018/06/28'])


################
# TEMPO

# add tempo at first measure: quarter = 90 (minutes per game) 
firstMeasure = groupStreamParts[0].measure(1)                         
firstMeasure.insert(0.0, tempo.MetronomeMark(number=90))


WMScore.show('text')
# Out:
# {0.0} <music21.metadata.Metadata object at 0x01935950>
# {0.0} <music21.stream.Part Group A>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.tempo.MetronomeMark maestoso Quarter=90>
#         {0.0} <music21.chord.Chord F4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord E-4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#         {1.0} <music21.chord.Chord E-4 C4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord C4 D4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {16.0} <music21.stream.Part Group B>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord E-4 E-4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord D4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 E4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {32.0} <music21.stream.Part Group C>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 C4>
#         {1.0} <music21.chord.Chord C4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E4 E-4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord E-4 E4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {48.0} <music21.stream.Part Group D>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C4 E-4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 D4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.chord.Chord D4 C4>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.chord.Chord E4 D4>
# {64.0} <music21.stream.Part Group E>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 D4>
#         {1.0} <music21.chord.Chord D4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord D4 C4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {80.0} <music21.stream.Part Group F>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord D4 C#4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 E-4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {96.0} <music21.stream.Part Group G>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord E-4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord F4 D4>
#         {1.0} <music21.chord.Chord F#4 C#4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 D4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord C4 D4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {112.0} <music21.stream.Part Group H>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 D4>
#         {1.0} <music21.chord.Chord C4 E-4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 E4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>

# %%
WMScore.show()

# %%
for match in matches:
    if match['matchDay'] > 3:
        print(match)
# Out:
# {'homeTeamCode': 'FRA', 'awayTeamCode': 'ARG', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 4, 'awayResult': 3}
# {'homeTeamCode': 'URU', 'awayTeamCode': 'POR', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 1}
# {'homeTeamCode': 'ESP', 'awayTeamCode': 'RUS', 'matchDay': 4, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 4}
# {'homeTeamCode': 'CRO', 'awayTeamCode': 'DEN', 'matchDay': 4, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 2}
# {'homeTeamCode': 'BRA', 'awayTeamCode': 'MEX', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0}
# {'homeTeamCode': 'BEL', 'awayTeamCode': 'JPN', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 3, 'awayResult': 2}
# {'homeTeamCode': 'SWE', 'awayTeamCode': 'SUI', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0}
# {'homeTeamCode': 'COL', 'awayTeamCode': 'ENG', 'matchDay': 4, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 4}
# {'homeTeamCode': 'URU', 'awayTeamCode': 'FRA', 'matchDay': 5, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 2}
# {'homeTeamCode': 'BRA', 'awayTeamCode': 'BEL', 'matchDay': 5, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2}
# {'homeTeamCode': 'SWE', 'awayTeamCode': 'ENG', 'matchDay': 5, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 2}
# {'homeTeamCode': 'RUS', 'awayTeamCode': 'CRO', 'matchDay': 5, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 4}
# {'homeTeamCode': 'FRA', 'awayTeamCode': 'BEL', 'matchDay': 6, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0}
# {'homeTeamCode': 'CRO', 'awayTeamCode': 'ENG', 'matchDay': 6, 'status': 'FINISHED', 'addition': 'n. V.', 'homeResult': 2, 'awayResult': 1}
# {'homeTeamCode': 'BEL', 'awayTeamCode': 'ENG', 'matchDay': 7, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0}
# {'homeTeamCode': 'FRA', 'awayTeamCode': 'CRO', 'matchDay': 8, 'status': 'FINISHED', 'homeResult': 4, 'awayResult': 2}

# %%
# iterate over matches
for match in matches:
    if match['matchDay'] > 3:
        # iterate over groups        
        # init shortcuts
        homeCode = match['homeTeamCode']
        awayCode = match['awayTeamCode']
        matchDay = match['matchDay']
        homeResult = match['homeResult']
        awayResult = match['awayResult']

        # add match results as pitchClasses to music21 note objects in groups dictionary
        homeNote = note.Note()
        awayNote = note.Note()
        homeNote.pitch.pitchClass = homeResult
        awayNote.pitch.pitchClass = awayResult

        # add group label to match dictionary
        match['group'] = groupKey

        # transform match results to chord objects with result strings as lyrics and add them all to match dictionary
        separator = ': '            
        match['gameChord'] = chord.Chord([homeNote, awayNote])
        match['gameChord'].addLyric(homeCode + separator + str(homeResult))
        match['gameChord'].addLyric(awayCode + separator + str(awayResult))
        if ('addition' in match):
            match['gameChord'].addLyric(match['addition'])
        print(match)
# Out:
# {'homeTeamCode': 'FRA', 'awayTeamCode': 'ARG', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 4, 'awayResult': 3, 'group': 'D', 'gameChord': <music21.chord.Chord E4 E-4>}
# {'homeTeamCode': 'URU', 'awayTeamCode': 'POR', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 1, 'group': 'D', 'gameChord': <music21.chord.Chord D4 C#4>}
# {'homeTeamCode': 'ESP', 'awayTeamCode': 'RUS', 'matchDay': 4, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 4, 'group': 'D', 'gameChord': <music21.chord.Chord E-4 E4>}
# {'homeTeamCode': 'CRO', 'awayTeamCode': 'DEN', 'matchDay': 4, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 2, 'group': 'D', 'gameChord': <music21.chord.Chord E-4 D4>}
# {'homeTeamCode': 'BRA', 'awayTeamCode': 'MEX', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0, 'group': 'D', 'gameChord': <music21.chord.Chord D4 C4>}
# {'homeTeamCode': 'BEL', 'awayTeamCode': 'JPN', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 3, 'awayResult': 2, 'group': 'D', 'gameChord': <music21.chord.Chord E-4 D4>}
# {'homeTeamCode': 'SWE', 'awayTeamCode': 'SUI', 'matchDay': 4, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0, 'group': 'D', 'gameChord': <music21.chord.Chord C#4 C4>}
# {'homeTeamCode': 'COL', 'awayTeamCode': 'ENG', 'matchDay': 4, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 4, 'group': 'D', 'gameChord': <music21.chord.Chord E-4 E4>}
# {'homeTeamCode': 'URU', 'awayTeamCode': 'FRA', 'matchDay': 5, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 2, 'group': 'D', 'gameChord': <music21.chord.Chord C4 D4>}
# {'homeTeamCode': 'BRA', 'awayTeamCode': 'BEL', 'matchDay': 5, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 2, 'group': 'D', 'gameChord': <music21.chord.Chord C#4 D4>}
# {'homeTeamCode': 'SWE', 'awayTeamCode': 'ENG', 'matchDay': 5, 'status': 'FINISHED', 'homeResult': 0, 'awayResult': 2, 'group': 'D', 'gameChord': <music21.chord.Chord C4 D4>}
# {'homeTeamCode': 'RUS', 'awayTeamCode': 'CRO', 'matchDay': 5, 'status': 'FINISHED', 'addition': 'n. E.', 'homeResult': 3, 'awayResult': 4, 'group': 'D', 'gameChord': <music21.chord.Chord E-4 E4>}
# {'homeTeamCode': 'FRA', 'awayTeamCode': 'BEL', 'matchDay': 6, 'status': 'FINISHED', 'homeResult': 1, 'awayResult': 0, 'group': 'D', 'gameChord': <music21.chord.Chord C#4 C4>}
# {'homeTeamCode': 'CRO', 'awayTeamCode': 'ENG', 'matchDay': 6, 'status': 'FINISHED', 'addition': 'n. V.', 'homeResult': 2, 'awayResult': 1, 'group': 'D', 'gameChord': <music21.chord.Chord D4 C#4>}
# {'homeTeamCode': 'BEL', 'awayTeamCode': 'ENG', 'matchDay': 7, 'status': 'FINISHED', 'homeResult': 2, 'awayResult': 0, 'group': 'D', 'gameChord': <music21.chord.Chord D4 C4>}
# {'homeTeamCode': 'FRA', 'awayTeamCode': 'CRO', 'matchDay': 8, 'status': 'FINISHED', 'homeResult': 4, 'awayResult': 2, 'group': 'D', 'gameChord': <music21.chord.Chord E4 D4>}

# %%
# group matches as chord pairs per matchday

# init
groupChordsByMatchDay = {}

# get matchDays with group matches as chord pairs
for i in range(4, 9):
    # iterate over matchDays (4-8)
    matchDayChordPairsList = []

    matchChordPairList = []
    for match in matches:
        # iterate over matches and check for correct matchday and group
        if match['matchDay'] == i:                       
            if 'gameChord' in match:
                # add existing chords to pair list
                matchChordPairList.append(match['gameChord'])
    if matchChordPairList:
        # add existing pair lists to matchday
        matchDayChordPairsList.append(matchChordPairList)
    # populate dictionary with matchdays and their resp. pair lists
    groupChordsByMatchDay[i] = matchDayChordPairsList
    
print(groupChordsByMatchDay)
# Out:
# {4: [[<music21.chord.Chord E4 E-4>, <music21.chord.Chord D4 C#4>, <music21.chord.Chord E-4 E4>, <music21.chord.Chord E-4 D4>, <music21.chord.Chord D4 C4>, <music21.chord.Chord E-4 D4>, <music21.chord.Chord C#4 C4>, <music21.chord.Chord E-4 E4>]], 5: [[<music21.chord.Chord C4 D4>, <music21.chord.Chord C#4 D4>, <music21.chord.Chord C4 D4>, <music21.chord.Chord E-4 E4>]], 6: [[<music21.chord.Chord C#4 C4>, <music21.chord.Chord D4 C#4>]], 7: [[<music21.chord.Chord D4 C4>]], 8: [[<music21.chord.Chord E4 D4>]]}

# %%
for matchDay, groupChordPairs in groupChordsByMatchDay.items():
    
    # add rests for empty game lines
    if matchDay == 5:
        for i in range(0, 4):
            if (2*i+1 < len(groupChordPairs[0])):
                groupChordPairs[0].insert(2*i+1, note.Rest(type='quarter'))
            else:
                groupChordPairs[0].append(note.Rest(type='quarter'))
    
    if matchDay == 6:
        for i in range(0, 2):
            groupChordPairs[0].insert(i, note.Rest(type='quarter'))
            groupChordPairs[0].append(note.Rest(type='quarter'))
        groupChordPairs[0].insert(3, note.Rest(type='quarter'))
        groupChordPairs[0].append(note.Rest(type='quarter'))
        
    if matchDay == 7:
        for i in range(0, 3):
            groupChordPairs[0].insert(i, note.Rest(type='quarter'))
            groupChordPairs[0].append(note.Rest(type='quarter'))
        groupChordPairs[0].append(note.Rest(type='quarter'))
    
    if matchDay == 8:
        for i in range(0, 3):
            groupChordPairs[0].insert(i, note.Rest(type='quarter'))
            groupChordPairs[0].append(note.Rest(type='quarter'))
        groupChordPairs[0].append(note.Rest(type='quarter'))
    
    print(matchDay, groupChordPairs)
# Out:
# 4 [[<music21.chord.Chord E4 E-4>, <music21.chord.Chord D4 C#4>, <music21.chord.Chord E-4 E4>, <music21.chord.Chord E-4 D4>, <music21.chord.Chord D4 C4>, <music21.chord.Chord E-4 D4>, <music21.chord.Chord C#4 C4>, <music21.chord.Chord E-4 E4>]]
# 5 [[<music21.chord.Chord C4 D4>, <music21.note.Rest rest>, <music21.chord.Chord C#4 D4>, <music21.note.Rest rest>, <music21.chord.Chord C4 D4>, <music21.note.Rest rest>, <music21.chord.Chord E-4 E4>, <music21.note.Rest rest>]]
# 6 [[<music21.note.Rest rest>, <music21.note.Rest rest>, <music21.chord.Chord C#4 C4>, <music21.note.Rest rest>, <music21.chord.Chord D4 C#4>, <music21.note.Rest rest>, <music21.note.Rest rest>, <music21.note.Rest rest>]]
# 7 [[<music21.note.Rest rest>, <music21.note.Rest rest>, <music21.note.Rest rest>, <music21.chord.Chord D4 C4>, <music21.note.Rest rest>, <music21.note.Rest rest>, <music21.note.Rest rest>, <music21.note.Rest rest>]]
# 8 [[<music21.note.Rest rest>, <music21.note.Rest rest>, <music21.note.Rest rest>, <music21.chord.Chord E4 D4>, <music21.note.Rest rest>, <music21.note.Rest rest>, <music21.note.Rest rest>, <music21.note.Rest rest>]]

# %%
# init
groupStreamParts = []     # empty list as container for groups as music21 stream.Part objects
matchDayMeasure

# init empty parts (stream.Part) for every group
# for i in range(len(groupLabel)):
#    groupString = 'Group ' + groupLabel[i]
#    groupStreamParts.append(stream.Part(id=groupString))
#    groupStreamParts[i].partName = groupString    
    

# populate groupStreamParts with groupChords
# iterate over matchdays
for matchDay, groupChordPairs in groupChordsByMatchDay.items():
    
    # iterate over groupChordPairs of a matchday
    for i in range(len(groupChordPairs)):
        
        # create music21 measure object with matchday as number
        matchDayMeasure = stream.Measure(number=matchDay)
        
         # iterate over every chord of a chordPair and append it to matchday measure
        for k in range(len(groupChordPairs[i])):
            matchDayMeasure.append(groupChordPairs[i][k])
        
        print(matchDayMeasure)
        matchDayMeasure.show()
        # check for match of i with length of part list
        # if i >= len(groupStreamParts):            
        #    break
        # append matchday measure to resp. part stream
        # groupStreamParts[i].append(matchDayMeasure)        

            
# create final WMScore stream object (stream.Stream)
# WMScore = stream.Stream(id='WMScore')

# append all groups (stream.Parts) to final WMScore (stream.Stream)
# appendListItemToStream(groupStreamParts, WMScore)

matchDayMeasure.show('text')
# Out:
# <music21.stream.Measure 4 offset=0.0>
# <music21.stream.Measure 5 offset=0.0>
# <music21.stream.Measure 6 offset=0.0>
# <music21.stream.Measure 7 offset=0.0>
# <music21.stream.Measure 8 offset=0.0>
# {0.0} <music21.note.Rest rest>
# {1.0} <music21.note.Rest rest>
# {2.0} <music21.note.Rest rest>
# {3.0} <music21.chord.Chord E4 D4>
# {4.0} <music21.note.Rest rest>
# {5.0} <music21.note.Rest rest>
# {6.0} <music21.note.Rest rest>
# {7.0} <music21.note.Rest rest>

# %%
WMScore.show('text')
# Out:
# {0.0} <music21.metadata.Metadata object at 0x01935950>
# {0.0} <music21.stream.Part Group A>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.tempo.MetronomeMark maestoso Quarter=90>
#         {0.0} <music21.chord.Chord F4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord E-4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#         {1.0} <music21.chord.Chord E-4 C4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord C4 D4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {16.0} <music21.stream.Part Group B>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord E-4 E-4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord D4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 E4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {32.0} <music21.stream.Part Group C>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 C4>
#         {1.0} <music21.chord.Chord C4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E4 E-4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord E-4 E4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {48.0} <music21.stream.Part Group D>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 C#4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C4 E-4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 D4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.chord.Chord D4 C4>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.chord.Chord E4 D4>
# {64.0} <music21.stream.Part Group E>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C#4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 D4>
#         {1.0} <music21.chord.Chord D4 D4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord D4 C4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.chord.Chord D4 C#4>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {80.0} <music21.stream.Part Group F>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C#4 C4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord D4 C#4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 E-4>
#         {1.0} <music21.chord.Chord D4 C4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord C#4 C4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {96.0} <music21.stream.Part Group G>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord E-4 C4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord F4 D4>
#         {1.0} <music21.chord.Chord F#4 C#4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 D4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.chord.Chord C4 D4>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
# {112.0} <music21.stream.Part Group H>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.chord.Chord C#4 D4>
#         {1.0} <music21.chord.Chord C#4 D4>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.chord.Chord D4 D4>
#         {1.0} <music21.chord.Chord C4 E-4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord C4 C#4>
#         {1.0} <music21.chord.Chord C4 C#4>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.chord.Chord E-4 E4>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.note.Rest rest>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.note.Rest rest>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.note.Rest rest>
